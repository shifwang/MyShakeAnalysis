# %% [markdown]
# ## Read Data Demo
#
# This is just a quick demo to show how to read data. Prepared by [Qingkai Kong](http://seismo.berkeley.edu/qingkaikong/).

# %%
import json
import matplotlib.pyplot as plt
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def get_data(data):
    '''
    helper function to get the timestamp and 3-component acceleration data. 
    '''
    # read in x, y, z data
    x = data['data']['x']
    y = data['data']['y']
    z = data['data']['z']

    # calculate the timestamp
    # get the start time
    t0 = data['header']['starttime']
    npoints = len(x)
    sampling_rate = data['header']['sampling_rate']
    
    # get the end time 
    t1 = t0 + npoints / sampling_rate
    
    # form the timestamp
    t = np.arange(t0, t1, 1/sampling_rate)
    return t, x, y, z

def plot_data(t, x, y, z):
    '''
    helper function to plot the 3-component acceleration data
    '''
    plt.subplot(311)
    plt.plot(t, x)
    plt.subplot(312)
    plt.plot(t, y)
    plt.ylabel('Acceleration (g)')
    plt.subplot(313)
    plt.plot(t, z)
    plt.xlabel('Time (sec)')
    plt.show()

# %% [markdown]
# ## Read simulated data

# %%
data = json.load(open('./data/EQ/simulated/', 'rb'))
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-6d20c179a6fe> in <module>()
# ----> 1 data = json.load(open('./data/EQ/simulated/', 'rb'))
#
# IOError: [Errno 2] No such file or directory: './data/EQ/simulated/'

# %%
t, x, y, z = get_data(data)
plot_data(t, x, y, z)

# %% [markdown]
# ## Read shake table data

# %%
data = json.load(open('./EQ/shake_table/trial142_phone3.json', 'rb'))

# %%
t, x, y, z = get_data(data)
rate = data['header']['sampling_rate'];
print len(x), len(t), rate
plot_data(t, x, y, z)
from matplotlib.pyplot import specgram
specgram(z, NFFT=100, Fs=rate, noverlap = 50);
# Out:
# 988 989 25.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-c0d1499fb6b4> in <module>()
#       2 rate = data['header']['sampling_rate'];
#       3 print len(x), len(t), rate
# ----> 4 plot_data(t, x, y, z)
#       5 from matplotlib.pyplot import specgram
#       6 specgram(z, NFFT=100, Fs=rate, noverlap = 50);
#
# <ipython-input-2-c013b80254cf> in plot_data(t, x, y, z)
#      26     '''
#      27     plt.subplot(311)
# ---> 28     plt.plot(t, x)
#      29     plt.subplot(312)
#      30     plt.plot(t, y)
#
# /usr/lib64/python2.7/site-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3159         ax.hold(hold)
#    3160     try:
# -> 3161         ret = ax.plot(*args, **kwargs)
#    3162     finally:
#    3163         ax.hold(washold)
#
# /usr/lib64/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /usr/lib64/python2.7/site-packages/matplotlib/axes/_axes.pyc in plot(self, *args, **kwargs)
#    1380         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1381
# -> 1382         for line in self._get_lines(*args, **kwargs):
#    1383             self.add_line(line)
#    1384             lines.append(line)
#
# /usr/lib64/python2.7/site-packages/matplotlib/axes/_base.pyc in _grab_next_args(self, *args, **kwargs)
#     379                 return
#     380             if len(remaining) <= 3:
# --> 381                 for seg in self._plot_args(remaining, kwargs):
#     382                     yield seg
#     383                 return
#
# /usr/lib64/python2.7/site-packages/matplotlib/axes/_base.pyc in _plot_args(self, tup, kwargs)
#     357             x, y = index_of(tup[-1])
#     358
# --> 359         x, y = self._xy_from_xy(x, y)
#     360
#     361         if self.command == 'plot':
#
# /usr/lib64/python2.7/site-packages/matplotlib/axes/_base.pyc in _xy_from_xy(self, x, y)
#     217         y = _check_1d(y)
#     218         if x.shape[0] != y.shape[0]:
# --> 219             raise ValueError("x and y must have same first dimension")
#     220         if x.ndim > 2 or y.ndim > 2:
#     221             raise ValueError("x and y can be no greater than 2-D")
#
# ValueError: x and y must have same first dimension

# %% [markdown]
# ## Read human data

# %%
data = json.load(open('./Human/013306004148017_1415046600.json', 'rb'))

# %%
t, x, y, z = get_data(data)
plot_data(t, x, y, z)
